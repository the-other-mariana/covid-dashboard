# %%
import pandas as pd
import numpy as np
import json

# %%
data_file = "../export_dataframe.xlsx"

# %%
xl = pd.ExcelFile(data_file)
covid_df = xl.parse("Sheet1")
covid_df.head()
# Out:
#   ID_REGISTRO ORIGEN   SECTOR ENTIDAD_UM    SEXO ENTIDAD_NAC ENTIDAD_RES  \
# 0      19de46    PUB     IMSS         DF  HOMBRE          TS          DF
# 1      033d67    PUB   ISSSTE         DF  HOMBRE          DF          DF
# 2      040b7b    PUB      SSA         DF   MUJER          MC          MC
# 3      0e4508    PUB   ISSSTE         DF   MUJER          DF          DF
# 4      1554ce   PRIV  PRIVADA         NT   MUJER          NT          NT
#
#     MUNICIPIO_RES TIPO_PACIENTE FECHA_INGRESO  ... FECHA_INGRESO_DY  \
# 0      CUAUHTÉMOC   AMBULATORIO    2020-01-01  ...                1
# 1  ÁLVARO OBREGÓN   AMBULATORIO    2020-01-01  ...                1
# 2         TECÁMAC   AMBULATORIO    2020-01-01  ...                1
# 3      IZTAPALAPA   AMBULATORIO    2020-01-01  ...                1
# 4           TEPIC   AMBULATORIO    2020-01-01  ...                1
#
#   FECHA_INGRESO_WK FECHA_SINTOMAS_YR FECHA_SINTOMAS_MT  FECHA_SINTOMAS_DY  \
# ...
